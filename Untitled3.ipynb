# %% [markdown]
# <a href="https://colab.research.google.com/github/kalpanaSharma20117/PW_DATA_ANALYTICS/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Regression

# %% [markdown]
# #### Ques1. What is Simple Linear Regression.

# %% [markdown]
# Ans. Simple Linear Regression is a statistical method used to model the relationship between two variables:
#
# One independent variable (X)
#
# One dependent variable (Y)
#
# It helps us predict the value of Y based on the value of X.

# %% [markdown]
# #### Ques2. What are the key assumptions of Simple Linear Regression?

# %% [markdown]
# Ans.
# 1. Linearity: The relationship between X and Y is linear.
#
# 2. Independence of errors : The residuals (errors) are independent.One prediction’s error should not affect the error of another.
#
# 3. Homoscedasticity: variance (spread) of the errors (residuals).No matter what value X takes, the error (difference between actual and predicted Y) should not grow or shrink — it should stay fairly even.
#
# 4. Normality of Errors: Residuals are normally distributed.
#
# 5. No Significant Outliers:
# Outliers can distort slope and intercept.

# %% [markdown]
# #### Ques3. What does the coefficient m represent in the equation Y = mX + c?

# %% [markdown]
# Ans. m is the slope of the line.It shows how much Y changes when X increases by 1 unit.If m = 4, then for every 1 unit increase in X, Y increases by 4 units.

# %% [markdown]
# #### Ques4. What does the intercept c represent in the equation Y = mX + c?

# %% [markdown]
# Ans. c is the Y-intercept.It is the value of Y when X = 0.
#  For example:
# If c = 20, then when X = 0, the predicted value of Y is 20.

# %% [markdown]
# #### Ques5.How do we calculate the slope m in Simple Linear Regression?

# %% [markdown]
# Ans. The slope 𝑚 is calculated using this formula:
#
# ![image.png](data:image/png;base64,...)
#
# X = average of X values
#
# 𝑌 = average of Y values
#
# Check how each X and Y deviate from the mean. Multiply those deviations together
#
# Divide the result by the total squared deviation of X.
#
# If the slope m = 1.5, which means:
#
# "For every 1 unit increase in X, Y increases by 1.5 units"

# %% [markdown]
# #### Ques6.  What is the purpose of the least squares method in Simple Linear Regression?

# %% [markdown]
# Ans. Least Squares Method helps us draw the best fit line through the data.Its purpose is to minimize the total squared error between actual Y values and predicted Y values by the line.
# If actual Y = 10 and predicted Y = 8, error = 2
# Square it → 2² = 4
# We do this for all points, and find the line with minimum total squared error.

# %% [markdown]
# #### QUes 7.  How is the coefficient of determination (R²) interpreted in Simple Linear Regression?

# %% [markdown]
# Ans.R² (R-squared) tells you how well your line fits the data.
# R² is the percentage of how much the independent variable (X) explains the variation in the dependent variable (Y).
# Let’s say you’re predicting someone’s salary (Y) based on their years of experience (X), and your model gives an R² = 0.80. "80% of the changes in salary can be explained by experience. The remaining 20% is due to other factors (like education, company, skills, etc.)"
# Higher R² = Better fit
#
# R² = 1 → Perfect prediction (rare in real life)
#
# R² = 0 → Model is not useful

# %% [markdown]
# #### Ques8. What is Multiple Linear Regression?

# %% [markdown]
# Ans. Multiple Linear Regression is like Simple Linear Regression, but with more than one X (input) variable.
# Y = Salary
#
# X₁ = Education level
#
# X₂ = Experience
#
# X₃ = Age
# It helps predict Y based on multiple factors.

# %% [markdown]
# #### Ques 9. What is the main difference between Simple and Multiple Linear Regression?

# %% [markdown]
# Ans. The main difference between Simple and Multiple Linear Regression is the number of input (independent) variables used to predict the output (dependent variable).
# 1.Simple Linear Regression Uses only ONE independent variable (X).
# 2. Multiple Linear Regression uses TWO or MORE independent variables (X₁, X₂, X₃…)

# %% [markdown]
# #### Ques10. What are the key assumptions of Multiple Linear Regression?

# %% [markdown]
# Ans.
# 1. Linearity – Relationship between X and Y is linear.
# 2. No Multicollinearity – Independent variables should not be highly correlated with each other.
# 3. Homoscedasticity – Errors should have constant variance.
# 4. Independence – Errors should be independent of each other.
# 5. Normality – Residuals (errors) should be normally distributed.

# %% [markdown]
# #### Ques11 . What is heteroscedasticity, and how does it affect the results of a Multiple Linear Regression model?

# %% [markdown]
# Ans. Heteroscedasticity means that the spread (variance) of the residuals (errors) is not constant across all levels of the independent variables.In a good regression model, we expect homoscedasticity: equal variance of errors everywhere.
# Effect of heteroscedasticity:
# 1. Coefficients (slopes) may still be correct, but the standard errors are wrong.
#
# 2.This leads to unreliable p-values, confidence intervals, and hypothesis tests.
#
# 3. It can mislead your interpretation of whether a variable is important or not.

# %% [markdown]
# #### Ques12. How can you improve a Multiple Linear Regression model with high multicollinearity?

# %% [markdown]
# Ans. Multicollinearity happens when two or more independent variables are highly correlated with each other.
# Makes it hard to tell which variable actually affects the outcome.
#
# Leads to unstable coefficients (values can flip signs or become huge).
#  Solutions:
#  1. Remove one of the correlated variables.
#  2. Combine them (e.g., average scores, sum, etc.)
#  3. Use regularization techniques like Ridge or Lasso regression.

# %% [markdown]
# #### Ques13.  What are some common techniques for transforming categorical variables for use in regression models?

# %% [markdown]
# Ans.  Categorical variables = non-numeric data (like Gender, City, Color).To use them in regression, convert them into numbers using:
# 1. Label Encoding:
# Converts categories to numbers (e.g., Male = 0, Female = 1).Works for ordinal data (like Low, Medium, High)
# 2. One-Hot Encoding:
# Creates separate columns for each category.e.g., City = [Delhi, Mumbai, Pune] → 3 new columns: is_Delhi, is_Mumbai, is_Pune.
# 3. Dummy Variables:Same as One-Hot, but removes one column to avoid multicollinearity

# %% [markdown]
# #### Ques14. What is the role of interaction terms in Multiple Linear Regression?

# %% [markdown]
# Ans. Interaction terms are used when you think two variables together affect Y differently than they do separately.
# Formula:
# If X₁ = hours studied, X₂ = sleep hours, you can add X₁ * X₂ as an interaction term.Maybe more sleep helps only if the student studied well. This interaction can be captured using the product of X₁ and X₂.

# %% [markdown]
# #### Ques15.How can the interpretation of intercept differ between Simple and Multiple Linear Regression?

# %% [markdown]
# Ans.  Intercept (b₀) = The value of Y when all X's = 0.
# In Simple Linear Regression, intercept means:
#
# Y value when X = 0
# In Multiple Linear Regression, intercept means:
#
# Y value when all independent variables = 0.
# Sometimes, the value of X = 0 may not be practical (e.g., 0 years of education), so the intercept may not always be meaningful.

# %% [markdown]
# #### Ques16. What is the significance of the slope in regression analysis, and how does it affect predictions.

# %% [markdown]
# Ans.The slope (also called the regression coefficient) shows the change in the dependent variable (Y) for every 1-unit increase in the independent variable (X).
# foe example: Y = mX +c
# m is the slope here,
# if m =2 , it means that for every 1 unit invcrease in X, Y increases by 2.
# The slope tells us the direction (positive/negative) and strength of the relationship between variables.

# %% [markdown]
# #### Ques17. How does the intercept in a regression model provide context for the relationship between variables?

# %% [markdown]
# Ans. The intercept (c or b₀) is the predicted value of Y when all X variables are zero.
# for example: Y = 2X + 5
# intercept = 5, it tells that when x =0, y=5.
#
# It helps set the starting point of the model. However, in some real-life situations(like age =0), it may not make any sense and can be ignored.

# %% [markdown]
# #### Ques18. What are the limitations of using R² as a sole measure of model performance?

# %% [markdown]
# Ans.R² tells us how well our model explains the variation in the target variable (Y). It’s useful, but if you use it alone to judge your model, it can mislead you. Here’s why:
# 1.  R² always increases when you add more variables, even if they’re not useful.This can make the model look better than it is (called overfitting).
#
# 2. High R² doesn’t mean the model is good at prediction. A model can fit the training data well but still perform poorly on new data.
#
# 3. R² doesn’t tell you if the relationship is real. Just because it fits doesn’t mean X is causing Y — it might just be a coincidence.
#
# R² is helpful, but not enough. Always look at other metrics too — like RMSE, MAE, residual plots, and adjusted R² — to truly understand how your model is performing.

# %% [markdown]
# #### Ques19. How would you interpret a large standard error for a regression coefficient?

# %% [markdown]
# Ans. A large standard error means the estimate of the coefficient (like the slope) is not precise.t implies more uncertainty in the coefficient. The coefficient may not be statistically significant.The confidence interval will be wide → difficult to trust the exact effect of that variable.
# It could mean:
#
# Too much noise in data
#
# Not enough data points
#
# Multicollinearity

# %% [markdown]
# #### Ques20. How can heteroscedasticity be identified in residual plots, and why is it important to address it?

# %% [markdown]
# Ans. Heteroscedasticity = Uneven spread of residuals (errors).
# How to identify:
# Plot residuals vs. predicted values.
# If you see a funnel shape (wider or narrower spread), then heteroscedasticity is present.
#
# Problem>> Makes standard errors incorrect.
# Leads to unreliable confidence intervals and p-values.Can mislead conclusions about which variables are important.
#
# solution:
# Transform variables
# Check for missing variables or outliers

# %% [markdown]
# #### Ques21. What does it mean if a Multiple Linear Regression model has a high R² but low adjusted R²?

# %% [markdown]
# Ans. It means your model is using too many unnecessary variables.R² always increases when you add more features, but adjusted R² only increases if the new variable actually helps.So, a high R² but low adjusted R² means your model may be overfitting — it's just memorizing instead of learning patterns.

# %% [markdown]
# #### Ques22. Why is it important to scale variables in Multiple Linear Regression?

# %% [markdown]
# Ans. Because different variables may have different units or ranges (like height in cm vs. salary in lakhs).
# If you don’t scale them, the model may give more importance to larger numbers, even if they aren't more important.
# Scaling (like StandardScaler or MinMaxScaler) makes the algorithm treat all features equally.

# %% [markdown]
# #### Ques23.What is Polynomial Regression?

# %% [markdown]
# Ans. Polynomial Regression is a type of regression where the relationship between the independent variable X and target Y is not a straight line, but a curved line.
# We fit the data using higher powers of X (like X², X³, etc.).

# %% [markdown]
# #### Ques24.How does Polynomial Regression differ from Linear Regression?

# %% [markdown]
# Ans. The key difference:
#
# Linear regression fits a straight line (linear relationship).
#
# Polynomial regression fits a curved line (non-linear relationship).
#
# Even though polynomial regression is non-linear in X, it is still linear in coefficients, so it’s still solved using linear methods.

# %% [markdown]
# #### Ques25. When is Polynomial Regression used?

# %% [markdown]
# Ans. When your data shows a non-linear pattern.
# If plotting X and Y gives a curve (not a straight line), polynomial regression gives a better fit than simple linear regression.
#
# Example:
# If your scatter plot looks like a U-shape or an S-curve, polynomial regression is a better choice.

# %% [markdown]
# #### Ques26. What is the general equation for polynomial regression?

# %% [markdown]
# Ans. ![WhatsApp Image 2025-05-31 at 22.24.37_6f0ff244.jpg](data:image/jpeg;base64,...)
#
# y = target variable
# x = input feature
#
# n = degree of the polynomial

# %% [markdown]
# #### Ques 27. Can polynomial regression be applied to multiple variables?

# %% [markdown]
# Ans.Yes, it's called Multivariate Polynomial Regression.
# You apply polynomial terms to each input variable.
# ![WhatsApp Image 2025-05-31 at 22.29.13_85b8732d.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### Ques 28.  What are the limitations of polynomial regression?

# %% [markdown]
# Ans.
# 1. Overfitting>>
# When you use a high-degree polynomial (like degree 6, 8, 10...), it may follow the training data too perfectly, including the noise and errors. This makes the model perform very well on training data but badly on new/unseen data.
#
# 2. Complexity>>
# As the degree of the polynomial increases, the equation becomes longer and harder to interpret. Also, calculations become slower, especially if you have many input features.
#
# 3. Extrapolation Issues>>
# Polynomial models behave unpredictably outside the range of your data.The curve might shoot up or down very fast when you try to predict values beyond what you've seen. If your data is between ages 10–50, and you try to predict for age 70 using a polynomial model — it might give a completely nonsense result like -100 or +1000, depending on the curve.
#
#  Polynomials bend too much outside your known data.
#
# 4. Sensitive to Outliers>>
# If there are a few extreme or wrong values in your data, a polynomial model will try hard to fit them, making the curve weird and less accurate overall.

# %% [markdown]
# #### Ques29. What methods can be used to evaluate model fit when selecting the degree of a polynomial?

# %% [markdown]
# Ans. These methods help you choose the right degree:
# 1. Train-Test Split>>
# You split your data into two parts:
#
#  Training Data → for building the model
#
#  Testing Data → for checking if it performs well on unseen data
#
#  Then try different degrees (like 1, 2, 3, 4...) and see which one gives lowest error on the test set.
#
#  Example:
# Suppose:
#
#  Degree 1 gives 15% error on test data
#
#  Degree 3 gives 10% error
#
#  egree 5 gives 8% error
#
#  Degree 10 gives 30% error (overfitting)
#
#  Pick degree 5, as it performs best on test data.
# 2. Cross-Validation (CV)>>
# You divide the data into multiple parts (folds) — like 5 or 10 equal pieces. Then:
#
#  Train on some parts
#
#  Test on the remaining
#
#  Repeat this process for all combinations
#
#  This helps you understand how the model performs on different subsets of data.
#
#  Why it's better than simple train-test:
# It gives more reliable results because it tests the model on different chunks of data — not just one test set.
#
#  Use CV to compare which degree consistently performs better across all data splits.
# 3. Evaluation Metrics>>
# These metrics tell you how good your model is. You use them to compare different polynomial degrees.
# R² (R-squared): Tells how much of the data is explained by the model (closer to 1 = better).
# RMSE (Root Mean Squared Error): Lower is better; measures error in same units as output.
# MAE (Mean Absolute Error): Also lower is better; measures average absolute error
# 4. Learning Curves>>
# ou plot model error vs. amount of training data, for both:
#
#  Training error
#
#  Validation error
#
#   This helps you visually detect if the model is:
#
#  Underfitting: Both errors are high and close
#
#  Overfitting: Training error is low, validation error is high
#
#  Good fit: Both errors are low and close
#
# Try different polynomial degrees and draw learning curves. The one that shows lowest and balanced errors is the best choice

# %% [markdown]
# #### Ques30.Why is visualization important in polynomial regression.

# %% [markdown]
# Ans. Polynomial regression fits a curved line to your data (unlike straight lines in simple linear regression). So, it can become very complex  based on the degree you choose.
#  Visualization helps you to See the curve, Detect Overfitting or Underfitting:If the curve is too wavy and fits every point perfectly → Overfitting , If the curve is too flat and misses patterns → Underfitting

# %% [markdown]
# #### Ques31. How is Polynomial Regression implemented in Python?

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# Sample data (X: independent variable, y: target variable)
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([2, 5, 10, 17, 26])  # y = x^2 + 1 approx.

# Step 1: Create polynomial features (degree 2)
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# Step 2: Fit Linear Regression on polynomial features
model = LinearRegression()
model.fit(X_poly, y)

# Step 3: Predict and visualize
y_pred = model.predict(X_poly)

# Plot
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X, y_pred, color='red', label='Polynomial Fit')
plt.title('Polynomial Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
